# %%
folder = 'results/vote1'

import glob
import pandas as pd

files = glob.glob(folder + "/*.csv")

full_df = None

for filename in files:
    if full_df is None:
        full_df = pd.read_csv(filename)
        full_df = full_df.drop(columns=['Id'])
        full_df = full_df.rename(columns={"ChargeOff": filename})
    else:
        df = pd.read_csv(filename)
        df = df.drop(columns=['Id'])
        df = df.rename(columns={"ChargeOff": filename})
        full_df = pd.concat([full_df, df], axis=1)

full_df['majority'] = full_df.mode(axis=1)[0]


pd.DataFrame(full_df['majority']).to_csv(folder +'.csv',header=['ChargeOff'],index_label="Id")

full_df.head(30)
# Out:
#     results/vote1\drop column.csv  results/vote1\full normalization.csv  \
# 0                               1                                     1
# 1                               0                                     0
# 2                               1                                     1
# 3                               0                                     0
# 4                               1                                     1
# 5                               0                                     0
# 6                               1                                     1
# 7                               1                                     1
# 8                               0                                     0
# 9                               0                                     0
# 10                              0                                     0
# 11                              0                                     0
# ...

# %%
folder = 'results/vote3'

import glob
import pandas as pd

files = glob.glob(folder + "/*.csv")

full_df = None

for filename in files:
    if full_df is None:
        full_df = pd.read_csv(filename)
        full_df = full_df.drop(columns=['Id'])
        full_df = full_df.rename(columns={"ChargeOff": filename})
    else:
        df = pd.read_csv(filename)
        df = df.drop(columns=['Id'])
        df = df.rename(columns={"ChargeOff": filename})
        full_df = pd.concat([full_df, df], axis=1)

full_df['majority'] = full_df.mode(axis=1)[0]


pd.DataFrame(full_df['majority']).to_csv(folder +'.csv',header=['ChargeOff'],index_label="Id")

full_df.head(30)
# Out:
#     results/vote3/gdboost.csv  results/vote3/RF_Best.csv  \
# 0                           1                          1
# 1                           0                          0
# 2                           1                          1
# 3                           0                          0
# 4                           1                          1
# 5                           0                          0
# 6                           1                          1
# 7                           1                          1
# 8                           0                          1
# 9                           0                          1
# 10                          0                          0
# 11                          0                          0
# 12                          1                          1
# 13                          1                          1
# 14                          0                          0
# ...
